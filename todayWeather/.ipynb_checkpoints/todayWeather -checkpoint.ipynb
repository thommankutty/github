# %%
# import modules here

# %%
import requests
from bs4 import BeautifulSoup as BS 
import pandas as pd 
import os

# %%
# import link here

# %%
link = r'http://www.weather.gov.sg/home'

# %%
# request on the link 
page = requests.get(link).content

# %%
# apply bs4 
content = BS(page, 'lxml')

# %%
content
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]--><!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]--><!--[if !(IE 7) & !(IE 8)]><!--><html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <!--<meta http-equiv="cache-control" content="max-age=0" />
# <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate" />
# <meta http-equiv="expires" content="0" />
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />
# <meta http-equiv="pragma" content="no-cache" />
# -->
# <meta content="public, max-age=60, must-revalidate" http-equiv="cache-control"/>
# <title>Home | </title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://www.weather.gov.sg/xmlrpc.php" rel="pingback"/>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/lib/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# ...

# %%
# find the data by class 
div_finder = content.find_all(class_ = 'row forecast-24')

# %%
div_finder.
# Out:
# [<div class="row forecast-24">
#  <div class="col-xs-5 title title-spacer">
#  <h1><a href="http://www.weather.gov.sg/weather-forecast-24hrforecast/">24-HOUR FORECAST</a></h1>
#  <br/><br/>
#  <p>Partly cloudy for rest of the day. For tomorrow, thundery showers over many areas in the late morning and early afternoon.</p>
#  </div>
#  <div class="col-xs-7">
# ...

# %%
name_box = content.find_all('div', attrs={'class': 'media-body media-middle'})

# %%
# find temp high
temp_high = name_box[0].find('h2').text

# %%
temp_high
# Out:
# '33°C'

# %%
# find temp low
temp_low = name_box[1].find('h2').text

# %%
temp_low
# Out:
# '25°C'

# %%
name_box
# Out:
# [<div class="media-body media-middle"> <h2>33°C</h2> </div>,
#  <div class="media-body media-middle"> <h2>25°C</h2> </div>,
#  <div class="media-body media-middle" style="padding-bottom:5px"><h2 style="padding-bottom:5px">33.6°C</h2><p>Pulau Ubin<br/>2.27 pm</p><br/></div>,
#  <div class="media-body media-middle" style="padding-bottom:5px"><h2 style="padding-bottom:5px">25.2°C</h2><p>Pulau Ubin<br/>6.08 am</p><br/></div>,
#  <div class="media-body media-middle" style="padding-bottom:5px"><h2 style="padding-bottom:5px">3.2 mm</h2><p>East Coast Parkway</p><br/></div>,
#  <div class="media-body media-middle"><h2 style="padding-bottom:5px">S&amp;nbsp33.5&amp;nbspkm/h</h2><p>East Coast Parkway</p><br/><p>3.37 pm</p></div>]

# %%
description = content.find_all('div', attrs={'class': 'col-xs-5 title title-spacer'})[0].find('p').text

# %%
date-description = description.find('p').text
# Out:
# 'Partly cloudy for rest of the day. For tomorrow, thundery showers over many areas in the late morning and early afternoon.'

# %%
description
# Out:
# 'Partly cloudy for rest of the day. For tomorrow, thundery showers over many areas in the late morning and early afternoon.'
